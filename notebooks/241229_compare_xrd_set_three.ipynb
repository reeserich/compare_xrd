# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# * [Dust mitigation from inclined hydrophobic and hydrophilic surfaces under electrostatic repulsion](https://pubpeer.com/publications/626C661BA2544CB7957FCE7AEA7660), *Journal of Electrostatics*, Figure 3C
# * [A novel method for dust mitigation from PV cell surfaces](https://pubpeer.com/publications/17352F76EF0DDBD95300AC0ABB4822), *Solar Energy*, Figure 4C
# * [Avalanche effect for chemically modified dust mitigation from surfaces](https://pubpeer.com/publications/C76259FA3DB1218479DFDAF7D1A28A), *Scientific Reports*. Figure 3
# * [Impacting Water Droplets Can Alleviate Dust from Slanted Hydrophobic Surfaces](https://doi.org/10.1021/acs.langmuir.1c00436), *Langmuir*, Figure 2C
# * [Environmental dust repelling from hydrophilic/hydrophobic surfaces under sonic excitations](https://pubpeer.com/publications/95D2C4B5500DB75EB4329ACF8062B7), *Scientific Reports*, Figure 6
# * [Adhesion characteristics of solution treated environmental dust](https://pubpeer.com/publications/87E1C90D90C0DA689E82362EAC8F57), *Scientific Reports*, Figure 3A

# %%
mineral_name = 'calcite'
rruff_id = 'R040070'
data_df = pd.read_csv('../data/calcite_R040070.txt', sep='\s+')
im = mpl.image.imread('../img/41598_2020_80811_Fig3_HTML.png')

fig = plt.figure(figsize=(10,10))
ax = plt.gca()

# calibration params
x_axis_height_pixels = 460
x_axis_start_deg= 20
x_axis_end_deg = 80
x_axis_start_pixels = 113
x_axis_end_pixels = 985

# style
multiplier = 2

def convert(convert):
    return x_axis_start_pixels + (x_axis_end_pixels - x_axis_start_pixels)*\
    (convert - x_axis_start_deg)/(x_axis_end_deg - x_axis_start_deg)

implot = ax.imshow(im, cmap='Greys_r')

# for calibration
#ax.plot([convert(20), convert(20)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)
#ax.plot([convert(80), convert(80)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)

for index, row in data_df.iterrows():
    two_theta = row['2-THETA']
    intensity = row['INTENSITY']
    if (two_theta > x_axis_start_deg) & (two_theta < x_axis_end_deg):
        ax.plot([convert(two_theta), convert(two_theta)], 
                [x_axis_height_pixels,x_axis_height_pixels-intensity*multiplier], 
                color='r', zorder=5)
        
ax.axis('off')
#ax.text(s='Author labels', x=650, y=280, rotation=90, color='r', size=16)
ax.text(s='Expected ' + mineral_name + ' peak positions\n(RRUFF ID ' + rruff_id +')', 
        x=980, y=560, ha='right', rotation=0, color='r', size=14)

label_top = 265
label_bottom = label_top + 60
ax.fill_between([270, 355], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')

label_top = 310
label_bottom = label_top + 60
ax.fill_between([495, 580], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')

label_top = 160
label_bottom = label_top + 35
ax.fill_between([410, 490], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')
fig.savefig('../img/set_three/241229_' + mineral_name + '_' + rruff_id + 'png', dpi=200, bbox_inches='tight')

# %%
mineral_name = 'quartz'
rruff_id = 'R040031'
data_df = pd.read_csv('../data/quartz_R040031.txt', sep='\s+')
im = mpl.image.imread('../img/41598_2020_80811_Fig3_HTML.png')

fig = plt.figure(figsize=(10,10))
ax = plt.gca()

# calibration params
x_axis_height_pixels = 460
x_axis_start_deg= 20
x_axis_end_deg = 80
x_axis_start_pixels = 113
x_axis_end_pixels = 985

# style
multiplier = 2

def convert(convert):
    return x_axis_start_pixels + (x_axis_end_pixels - x_axis_start_pixels)*\
    (convert - x_axis_start_deg)/(x_axis_end_deg - x_axis_start_deg)

implot = ax.imshow(im, cmap='Greys_r')

# for calibration
#ax.plot([convert(20), convert(20)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)
#ax.plot([convert(80), convert(80)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)

for index, row in data_df.iterrows():
    two_theta = row['2-THETA']
    intensity = row['INTENSITY']
    if (two_theta > x_axis_start_deg) & (two_theta < x_axis_end_deg):
        ax.plot([convert(two_theta), convert(two_theta)], 
                [x_axis_height_pixels,x_axis_height_pixels-intensity*multiplier], 
                color='r', zorder=5)
        
ax.axis('off')
#ax.text(s='Author labels', x=650, y=280, rotation=90, color='r', size=16)
ax.text(s='Expected ' + mineral_name + ' peak positions\n(RRUFF ID ' + rruff_id +')', 
        x=980, y=560, ha='right', rotation=0, color='r', size=14)

label_top = 35
label_bottom = label_top + 35
ax.fill_between([200, 255], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')

label_top = 310
label_bottom = label_top + 35
ax.fill_between([125, 185], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')

label_top = 375
label_bottom = label_top + 35
ax.fill_between([595, 655], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')
fig.savefig('../img/set_three/241229_' + mineral_name + '_' + rruff_id + 'png', dpi=200, bbox_inches='tight')

# %%
mineral_name = 'sylvite'
rruff_id = 'R050166'
data_df = pd.read_csv('../data/sylvite_R050166.txt', sep='\s+')
im = mpl.image.imread('../img/41598_2020_80811_Fig3_HTML.png')

fig = plt.figure(figsize=(10,10))
ax = plt.gca()

# calibration params
x_axis_height_pixels = 460
x_axis_start_deg= 20
x_axis_end_deg = 80
x_axis_start_pixels = 113
x_axis_end_pixels = 985

# style
multiplier = 2

def convert(convert):
    return x_axis_start_pixels + (x_axis_end_pixels - x_axis_start_pixels)*\
    (convert - x_axis_start_deg)/(x_axis_end_deg - x_axis_start_deg)

implot = ax.imshow(im, cmap='Greys_r')

# for calibration
#ax.plot([convert(20), convert(20)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)
#ax.plot([convert(80), convert(80)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)

for index, row in data_df.iterrows():
    two_theta = row['2-THETA']
    intensity = row['INTENSITY']
    if (two_theta > x_axis_start_deg) & (two_theta < x_axis_end_deg):
        ax.plot([convert(two_theta), convert(two_theta)], 
                [x_axis_height_pixels,x_axis_height_pixels-intensity*multiplier], 
                color='r', zorder=5)
        
ax.axis('off')
#ax.text(s='Author labels', x=650, y=280, rotation=90, color='r', size=16)
ax.text(s='Expected ' + mineral_name + ' peak positions\n(RRUFF ID ' + rruff_id +')', 
        x=980, y=560, ha='right', rotation=0, color='r', size=14)

label_top = 55
label_bottom = label_top + 80
ax.fill_between([260, 335], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')

fig.savefig('../img/set_three/241229_' + mineral_name + '_' + rruff_id + 'png', dpi=200, bbox_inches='tight')

# %%
mineral_name = 'corundum'
rruff_id = 'R040096'
data_df = pd.read_csv('../data/corundum_R040096.txt', sep='\s+')
im = mpl.image.imread('../img/41598_2020_80811_Fig3_HTML.png')

fig = plt.figure(figsize=(10,10))
ax = plt.gca()

# calibration params
x_axis_height_pixels = 460
x_axis_start_deg= 20
x_axis_end_deg = 80
x_axis_start_pixels = 113
x_axis_end_pixels = 985

# style
multiplier = 2

def convert(convert):
    return x_axis_start_pixels + (x_axis_end_pixels - x_axis_start_pixels)*\
    (convert - x_axis_start_deg)/(x_axis_end_deg - x_axis_start_deg)

implot = ax.imshow(im, cmap='Greys_r')

# for calibration
#ax.plot([convert(20), convert(20)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)
#ax.plot([convert(80), convert(80)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)

for index, row in data_df.iterrows():
    two_theta = row['2-THETA']
    intensity = row['INTENSITY']
    if (two_theta > x_axis_start_deg) & (two_theta < x_axis_end_deg):
        ax.plot([convert(two_theta), convert(two_theta)], 
                [x_axis_height_pixels,x_axis_height_pixels-intensity*multiplier], 
                color='r', zorder=5)
        
ax.axis('off')
#ax.text(s='Author labels', x=650, y=280, rotation=90, color='r', size=16)
ax.text(s='Expected ' + mineral_name + ' peak positions\n(RRUFF ID ' + rruff_id +')', 
        x=980, y=560, ha='right', rotation=0, color='r', size=14)

label_top = 220
label_bottom = label_top + 35
ax.fill_between([460, 650], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')

label_top = 260
label_bottom = label_top + 35
ax.fill_between([820, 890], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')

label_top = 250
label_bottom = label_top + 35
ax.fill_between([910, 980], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')

fig.savefig('../img/set_three/241229_' + mineral_name + '_' + rruff_id + 'png', dpi=200, bbox_inches='tight')

# %%
mineral_name = 'halite'
rruff_id = 'R070292'
data_df = pd.read_csv('../data/halite_R070292.txt', sep='\s+')
im = mpl.image.imread('../img/41598_2020_80811_Fig3_HTML.png')

fig = plt.figure(figsize=(10,10))
ax = plt.gca()

# calibration params
x_axis_height_pixels = 460
x_axis_start_deg= 20
x_axis_end_deg = 80
x_axis_start_pixels = 113
x_axis_end_pixels = 985

# style
multiplier = 2

def convert(convert):
    return x_axis_start_pixels + (x_axis_end_pixels - x_axis_start_pixels)*\
    (convert - x_axis_start_deg)/(x_axis_end_deg - x_axis_start_deg)

implot = ax.imshow(im, cmap='Greys_r')

# for calibration
#ax.plot([convert(20), convert(20)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)
#ax.plot([convert(80), convert(80)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)

for index, row in data_df.iterrows():
    two_theta = row['2-THETA']
    intensity = row['INTENSITY']
    if (two_theta > x_axis_start_deg) & (two_theta < x_axis_end_deg):
        ax.plot([convert(two_theta), convert(two_theta)], 
                [x_axis_height_pixels,x_axis_height_pixels-intensity*multiplier], 
                color='r', zorder=5)
        
ax.axis('off')
#ax.text(s='Author labels', x=650, y=280, rotation=90, color='r', size=16)
ax.text(s='Expected ' + mineral_name + ' peak positions\n(RRUFF ID ' + rruff_id +')', 
        x=980, y=560, ha='right', rotation=0, color='r', size=14)

label_top = 345
label_bottom = label_top + 35
ax.fill_between([750, 830], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')

fig.savefig('../img/set_three/241229_' + mineral_name + '_' + rruff_id + 'png', dpi=200, bbox_inches='tight')

# %%
mineral_name = 'dolomite'
rruff_id = 'R040030'
data_df = pd.read_csv('../data/dolomite_R040030.txt', sep='\s+')
im = mpl.image.imread('../img/41598_2020_80811_Fig3_HTML.png')

fig = plt.figure(figsize=(10,10))
ax = plt.gca()

# calibration params
x_axis_height_pixels = 460
x_axis_start_deg= 20
x_axis_end_deg = 80
x_axis_start_pixels = 113
x_axis_end_pixels = 985

# style
multiplier = 2

def convert(convert):
    return x_axis_start_pixels + (x_axis_end_pixels - x_axis_start_pixels)*\
    (convert - x_axis_start_deg)/(x_axis_end_deg - x_axis_start_deg)

implot = ax.imshow(im, cmap='Greys_r')

# for calibration
#ax.plot([convert(20), convert(20)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)
#ax.plot([convert(80), convert(80)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)

for index, row in data_df.iterrows():
    two_theta = row['2-THETA']
    intensity = row['INTENSITY']
    if (two_theta > x_axis_start_deg) & (two_theta < x_axis_end_deg):
        ax.plot([convert(two_theta), convert(two_theta)], 
                [x_axis_height_pixels,x_axis_height_pixels-intensity*multiplier], 
                color='r', zorder=5)
        
ax.axis('off')
#ax.text(s='Author labels', x=650, y=280, rotation=90, color='r', size=16)
ax.text(s='Expected ' + mineral_name + ' peak positions\n(RRUFF ID ' + rruff_id +')', 
        x=980, y=560, ha='right', rotation=0, color='r', size=14)

label_top = 135
label_bottom = label_top + 35
ax.fill_between([690, 780], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')

fig.savefig('../img/set_three/241229_' + mineral_name + '_' + rruff_id + 'png', dpi=200, bbox_inches='tight')

# %%
mineral_name = 'anhydrite'
rruff_id = 'R040012'
data_df = pd.read_csv('../data/anhydrite_R040012.txt', sep='\s+')
im = mpl.image.imread('../img/41598_2020_80811_Fig3_HTML.png')

fig = plt.figure(figsize=(10,10))
ax = plt.gca()

# calibration params
x_axis_height_pixels = 460
x_axis_start_deg= 20
x_axis_end_deg = 80
x_axis_start_pixels = 113
x_axis_end_pixels = 985

# style
multiplier = 2

def convert(convert):
    return x_axis_start_pixels + (x_axis_end_pixels - x_axis_start_pixels)*\
    (convert - x_axis_start_deg)/(x_axis_end_deg - x_axis_start_deg)

implot = ax.imshow(im, cmap='Greys_r')

# for calibration
#ax.plot([convert(20), convert(20)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)
#ax.plot([convert(80), convert(80)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)

for index, row in data_df.iterrows():
    two_theta = row['2-THETA']
    intensity = row['INTENSITY']
    if (two_theta > x_axis_start_deg) & (two_theta < x_axis_end_deg):
        ax.plot([convert(two_theta), convert(two_theta)], 
                [x_axis_height_pixels,x_axis_height_pixels-intensity*multiplier], 
                color='r', zorder=5)
        
ax.axis('off')
#ax.text(s='Author labels', x=650, y=280, rotation=90, color='r', size=16)
ax.text(s='Expected ' + mineral_name + ' peak positions\n(RRUFF ID ' + rruff_id +')', 
        x=980, y=560, ha='right', rotation=0, color='r', size=14)

label_top = 300
label_bottom = label_top + 65
ax.fill_between([850, 960], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')

label_top = 335
label_bottom = label_top + 35
ax.fill_between([575, 650], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')
ax.text(s='?', 
        x=670, y=370, ha='right', rotation=0, color='r', size=18)

label_top = 140
label_bottom = label_top + 35
ax.fill_between([240, 320], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')
ax.text(s='?', 
        x=340, y=160, ha='right', rotation=0, color='r', size=18)

fig.savefig('../img/set_three/241229_' + mineral_name + '_' + rruff_id + 'png', dpi=200, bbox_inches='tight')

# %%
mineral_name = 'gypsum'
rruff_id = 'R040029'
data_df = pd.read_csv('../data/gypsum_R040029.txt', sep='\s+')
im = mpl.image.imread('../img/41598_2020_80811_Fig3_HTML.png')

fig = plt.figure(figsize=(10,10))
ax = plt.gca()

# calibration params
x_axis_height_pixels = 460
x_axis_start_deg= 20
x_axis_end_deg = 80
x_axis_start_pixels = 113
x_axis_end_pixels = 985

# style
multiplier = 2

def convert(convert):
    return x_axis_start_pixels + (x_axis_end_pixels - x_axis_start_pixels)*\
    (convert - x_axis_start_deg)/(x_axis_end_deg - x_axis_start_deg)

implot = ax.imshow(im, cmap='Greys_r')

# for calibration
#ax.plot([convert(20), convert(20)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)
#ax.plot([convert(80), convert(80)], [x_axis_height_pixels,x_axis_height_pixels-100], color='g', zorder=5)

for index, row in data_df.iterrows():
    two_theta = row['2-THETA']
    intensity = row['INTENSITY']
    if (two_theta > x_axis_start_deg) & (two_theta < x_axis_end_deg):
        ax.plot([convert(two_theta), convert(two_theta)], 
                [x_axis_height_pixels,x_axis_height_pixels-intensity*multiplier], 
                color='r', zorder=5)
        
ax.axis('off')
#ax.text(s='Author labels', x=650, y=280, rotation=90, color='r', size=16)
ax.text(s='Expected ' + mineral_name + ' peak positions\n(RRUFF ID ' + rruff_id +')', 
        x=980, y=560, ha='right', rotation=0, color='r', size=14)


label_top = 335
label_bottom = label_top + 35
ax.fill_between([575, 650], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')
ax.text(s='?', 
        x=670, y=370, ha='right', rotation=0, color='r', size=18)

label_top = 140
label_bottom = label_top + 35
ax.fill_between([240, 320], 
                y1=[label_bottom,label_bottom], 
                y2=[label_top,label_top], linewidth=2, edgecolor='r', facecolor='none')
ax.text(s='?', 
        x=340, y=160, ha='right', rotation=0, color='r', size=18)

fig.savefig('../img/set_three/241229_' + mineral_name + '_' + rruff_id + 'png', dpi=200, bbox_inches='tight')
